# %% [markdown]
# <a href="https://colab.research.google.com/github/EUtrilla2002/ProyectoDatos/blob/main/1-Preprocesamiento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Análisis de datos

# %% [markdown]
# ## Bases de datos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Datos/contenido_zip/base_limpia_tipos.csv")  # Primera base de datos
print(df["categoria"].value_counts())
# Out:
# categoria
# neutral     254295
# negativo    254295
# positivo    254295
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    review/score                                        review/text categoria
# 0           3.0  I completely agree with some of the reviewers ...   neutral
# 1           2.0  When an RPG promises over 50 hours of gameplay...  negativo
# 2           3.0  This book started out meeting my expectations ...   neutral
# 3           5.0  I read this book for the 1st time last month. ...  positivo
# 4           3.0  Alice's adventures in wonderland. Alice was ge...   neutral

# %% [markdown]
# ## Separación entre train y test de la base de datos

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# 1. Split
X = df['review/text']
y = df['categoria']

# %% [markdown]
# ## Limpieza de texto

# %%
print(df[df['categoria'] == 'positivo']['review/text'].head())  # Primeras 5 reseñas positivas
print(df[df['categoria'] == 'negativo']['review/text'].head())  # Primeras 5 reseñas negativas
# Out:
# 3     I read this book for the 1st time last month. ...
# 5     Interesting and unusual novel. I particularly ...
# 7     We have lingered too long on the so-called, an...
# 8     I am a college student at St. John Fisher coll...
# 20    As any serious readers of romance novels knows...
# Name: review/text, dtype: object
# 1     When an RPG promises over 50 hours of gameplay...
# 6     Romance purists should beware. This author see...
# 9     Not worth my time especially for a book club.....
# 10    Book was ok - it told you all that we know abo...
# 12    I wanted to like this book - I really did. A b...
# Name: review/text, dtype: object

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords

# Asegúrate de tener descargadas las stopwords de nltk
nltk.download('stopwords')

stopwords_libros = {'book', 'read', 'novel', 'story', 'books', 'reading', 'author', 'chapter', 'reader', 'reading', 'writting', 'one', 'quot', 'would', 'review'}

# Obtener las stopwords comunes en inglés de NLTK
stopwords_comunes = set(stopwords.words('english'))

stopwords_verbos= {'like', 'time', 'know', 'make', 'people', 'good', 'really', 'think', 'get', 'want', 'love', 'seem', 'much', 'even', 'work', 'take', 'find', 'first', 'lot', 'also', 'see', 'really', 'character'}

# Combinar ambas listas de stopwords
stopwords_totales = stopwords_libros.union(stopwords_comunes)
stopwords_totales = stopwords_totales.union(stopwords_verbos)

# Asumimos que 'categoria' es la columna con las categorías (Positivo, Negativo, Neutral)
# Filtramos las reseñas positivas
positivas = df[df['categoria'] == 'positivo']['review/text'].str.cat(sep=" ")

# Configuramos la nube de palabras, incluyendo las stopwords combinadas
wc = WordCloud(
    width=500,
    height=500,
    min_font_size=15,
    background_color='white',
    stopwords=stopwords_totales  # Añadimos las stopwords combinadas
)

# Nube de palabras para las reseñas positivas
positivas_wc = wc.generate(positivas)
# Mostramos la nube de palabras positiva
plt.figure(figsize=(7, 7))
plt.axis('off')
plt.title('Nube de palabras - Positivas')
plt.imshow(positivas_wc)
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
import html

# Lista de stopwords personalizadas
stopwords_libros = {'book', 'read', 'novel', 'story', 'books', 'reading', 'author', 'chapter', 'reader', 'reading', 'writing', 'one', 'quot', 'would', 'review', 'page', 'word'}

# Obtener las stopwords comunes en inglés de NLTK
from nltk.corpus import stopwords
stopwords_comunes = set(stopwords.words('english'))

# Lista de stopwords de verbos
stopwords_verbos = {'time', 'know', 'make', 'people', 'good', 'really', 'think', 'get', 'want', 'seem', 'much', 'even', 'work', 'take', 'find', 'first', 'lot', 'also', 'see', 'really'}

# Combinar todas las listas de stopwords
stopwords_totales = stopwords_libros.union(stopwords_comunes).union(stopwords_verbos)

# Convertir el conjunto de stopwords a lista
stopwords_totales = list(stopwords_totales)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %% [markdown]
# ## Tokenización y análisis de palabras

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


# Preprocesamiento con TfidfVectorizer usando las stopwords personalizadas
vectorizer = TfidfVectorizer(stop_words=stopwords_totales)  # Pasamos las stopwords personalizadas

# Transformar los datos
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder
import numpy as np


# Entrenar el modelo de regresión logística con los datos transformados (y_train_onehot)
modelo_lr = LogisticRegression(max_iter=1000)
modelo_lr.fit(X_train_vec, y_train)  # X_train_vec son las características, y_train_onehot son las etiquetas codificadas

# Realizar predicciones sobre el conjunto de prueba
y_pred = modelo_lr.predict(X_test_vec)

# Evaluar el rendimiento del modelo (usando precisión en este caso)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")

# %%
# Mostrar la matriz de confusión
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=modelo_lr.classes_, yticklabels=modelo_lr.classes_)
plt.title("Matriz de Confusión")
plt.xlabel("Predicciones")
plt.ylabel("Verdaderas Etiquetas")
plt.show()

# Reporte de clasificación: precisión, recuperación y F1 para cada clase
print("\nReporte de Clasificación:")
print(classification_report(y_test, y_pred))

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

# Definir los parámetros que queremos probar
param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],  # Valores de C (regularización)
    'solver': ['lbfgs', 'liblinear', 'saga'],  # Solvers disponibles
    'penalty': ['l2'],  # Tipo de regularización (l2 o l1)
    'max_iter': [100, 200],  # Número máximo de iteraciones
}

# Crear el modelo de regresión logística
modelo_lr = LogisticRegression()

# Crear el objeto GridSearchCV con validación cruzada de 5 pliegues
grid_search = GridSearchCV(estimator=modelo_lr, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1, verbose=1)

# Ajustar el GridSearch con los datos de entrenamiento
grid_search.fit(X_train_vec, y_train)

# Ver los mejores parámetros encontrados
print("Mejores parámetros:", grid_search.best_params_)

# Evaluar el rendimiento del modelo ajustado
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test_vec)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy después del ajuste de hiperparámetros: {accuracy:.4f}")
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-ef418f174210> in <cell line: 0>()
#      17
#      18 # Ajustar el GridSearch con los datos de entrenamiento
# ---> 19 grid_search.fit(X_train_vec, y_train)
#      20
#      21 # Ver los mejores parámetros encontrados
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, **params)
#    1022                 return results
#    1023
# -> 1024             self._run_search(evaluate_candidates)
#    1025
# ...
